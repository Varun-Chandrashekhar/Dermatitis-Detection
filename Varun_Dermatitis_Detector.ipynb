# %% [markdown]
# #Updating Enviornment

# %%
# !pip install -U ipykernel
# Out:
# Requirement already up-to-date: ipykernel in /usr/local/lib/python3.6/dist-packages (5.3.4)
# ...

# %%
# !pip install -q streamlit

# %%
pip install --upgrade Pillow
# Out:
# Requirement already up-to-date: Pillow in /usr/local/lib/python3.6/dist-packages (8.0.1)

# %%
# !pip install pyngrok

# %%
from pyngrok import ngrok
# !pgrep streamlit
ngrok.kill()

# %% [markdown]
# # Importing Libraries

# %%
import streamlit as st # Web application
from PIL import Image # Image processing
import requests # image URL requesting
from io import BytesIO # Image conversion
import csv
import os
import urllib


import numpy as np # linear algebra
import pandas as pd # data processing

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
from fastai.vision import *
from fastai.imports import *
path = Path('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/data/dermatitis')

# %% [markdown]
# #Downloading Images from URLs

# %%
download_images('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/data/dermatitis/eczema/eczema.csv', '/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/data/dermatitis/eczema', max_pics=400)
# Out:
# Error https://www.usnews.com/dims4/USNEWS/fa71584/2147483647/thumbnail/640x420/quality/85/?url=http%3A%2F%2Fcom-usnews-beam-media.s3.amazonaws.com%2Fc3%2F3f%2F3796a84b4397b031f57cad24ee6e%2F160922-skinrash-stock.jpg HTTPSConnectionPool(host='www.usnews.com', port=443): Read timed out. (read timeout=4)
# Error https://smhttp-ssl-48324.nexcesscdn.net/media/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/k/a/kamedis-eczema-therapy-cream_1.jpg HTTPSConnectionPool(host='smhttp-ssl-48324.nexcesscdn.net', port=443): Max retries exceeded with url: /media/catalog/product/cache/1/image/9df78eab33525d08d6e5fb8d27136e95/k/a/kamedis-eczema-therapy-cream_1.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fda4ab1ef98>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# ...

# %%
download_images('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/data/dermatitis/measles/measles.csv', '/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/data/dermatitis/measles', max_pics=400)
# Out:
# Error https://cdn1.medicalnewstoday.com/content/images/hero/164/164504/164504_1100.jpg HTTPSConnectionPool(host='cdn1.medicalnewstoday.com', port=443): Max retries exceeded with url: /content/images/hero/164/164504/164504_1100.jpg (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7fda4af7dda0>: Failed to establish a new connection: [Errno -2] Name or service not known',))
# Error https://news.images.itv.com/image/file/1508318/stream_img.jpg HTTPSConnectionPool(host='news.images.itv.com', port=443): Read timed out. (read timeout=4)
# Error https://news.images.itv.com/image/file/1617187/stream_img.jpg HTTPSConnectionPool(host='news.images.itv.com', port=443): Read timed out. (read timeout=4)
# ...

# %%
download_images('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/data/dermatitis/melanoma/melanoma.csv', '/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/data/dermatitis/melanoma', max_pics=400)
# Out:
# Error https://www.derm101.com/wp-content/uploads/dp0802a06g004.jpg HTTPSConnectionPool(host='www.derm101.com', port=443): Max retries exceeded with url: /wp-content/uploads/dp0802a06g004.jpg (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:852)'),))
# ...

# %% [markdown]
# #Deleting Corrupt Images

# %%
classes = ['eczema','measles','melanoma']

# %%
path = Path('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/data/dermatitis')
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_size=500)
# Out:
# eczema
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1007: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# cannot identify image file <_io.BufferedReader name='/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/data/dermatitis/eczema/00000112.jpg'>
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1007: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py:1007: UserWarning: Couldn't allocate palette entry for transparency
#   warnings.warn("Couldn't allocate palette entry for transparency")
# cannot identify image file <_io.BufferedReader name='/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/data/dermatitis/eczema/00000153.jpg'>
# ...

# %% [markdown]
# # View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
# If you already cleaned your data, run this cell instead of the one before
# np.random.seed(42)
# data = ImageDataBunch.from_csv(path, folder=".", valid_pct=0.2, csv_labels='cleaned.csv',
#         ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['eczema', 'measles', 'melanoma']

# %%
data.show_batch(rows=3, figsize=(7,8))
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['eczema', 'measles', 'melanoma'], 3, 788, 197)

# %% [markdown]
# # Train model

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet34-333f7ec4.pth" to /root/.cache/torch/hub/checkpoints/resnet34-333f7ec4.pth
# ...

# %%
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.633412</td>
#       <td>0.959374</td>
#       <td>0.340102</td>
#       <td>04:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.316420</td>
#       <td>0.845113</td>
#       <td>0.274112</td>
#       <td>04:37</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.111982</td>
#       <td>0.819847</td>
#       <td>0.253807</td>
#       <td>04:38</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.942478</td>
#       <td>0.884833</td>
#       <td>0.269036</td>
#       <td>04:39</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.852884</td>
#       <td>0.866996</td>
#       <td>0.269036</td>
#       <td>04:39</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='6' class='' max='9' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       66.67% [6/9 36:57<18:28]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
# ...

# %%
# If the plot is not showing try to give a start and end learning rate
#learn.lr_find(start_lr=1e-03, end_lr=1e-04)
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-8,3e-6))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.351319</td>
#       <td>0.709204</td>
#       <td>0.243655</td>
#       <td>06:39</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.345114</td>
#       <td>0.712220</td>
#       <td>0.248731</td>
#       <td>06:36</td>
#     </tr>
#   </tbody>
# </table>
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
learn.save('stage-2')

# %% [markdown]
# # Interpretation

# %%
learn.load('stage-2');

# %%
interp = ClassificationInterpretation.from_learner(learn)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# # Cleaning Up

# %%
from fastai.widgets import *

# %%
db = (ImageList.from_folder(path)
                   .split_none()
                   .label_from_folder()
                   .transform(get_transforms(), size=224)
                   .databunch()
     )
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
# If you already cleaned your data using indexes from `from_toplosses`,
# run this cell instead of the one before to proceed with removing duplicates.
# Otherwise all the results of the previous step would be overwritten by
# the new run of `ImageCleaner`.

# db = (ImageList.from_csv(path, 'cleaned.csv', folder='.')
#                    .no_split()
#                    .label_from_df()
#                    .transform(get_transforms(), size=224)
#                    .databunch()
#      )

# %% [markdown]
# Then we create a new learner to use our new databunch with all the images.

# %%
learn_cln = cnn_learner(db, models.resnet34, metrics=error_rate)

learn_cln.load('stage-2');

# %%
ds, idxs = DatasetFormatter().from_toplosses(learn_cln)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %% [markdown]
# Make sure you're running this notebook in Jupyter Notebook, not Jupyter Lab. That is accessible via [/tree](/tree), not [/lab](/lab). Running the `ImageCleaner` widget in Jupyter Lab is [not currently supported](https://github.com/fastai/fastai/issues/1539).

# %%
# Don't run this in google colab or any other instances running jupyter lab.
# If you do run this on Jupyter Lab, you need to restart your runtime and
# runtime state including all local variables will be lost.
ImageCleaner(ds, idxs, path)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %%
ds, idxs = DatasetFormatter().from_similars(learn_cln)
# Out:
# Getting activations...
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='16' class='' max='16' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [16/16 03:30<00:00]
#     </div>
# Computing similarities...

# %%
ImageCleaner(ds, idxs, path, duplicates=True)
# Out:
# ...
# Button(button_style='primary', description='Next Batch', layout=Layout(width='auto'), style=ButtonStyle())

# %% [markdown]
# Remember to recreate your ImageDataBunch from your `cleaned.csv` to include the changes you made in your data!

# %%
data_cleaned = ImageDataBunch.from_csv(path, csv_labels='cleaned.csv',
                                       label_col=1,
                                       valid_pct=0.2,
                                       ds_tfms=get_transforms(), size=224, 
                                       num_workers=0).normalize(imagenet_stats)
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
#   warnings.warn("The default behavior for interpolate/upsample with float scale_factor changed "
# /usr/local/lib/python3.6/dist-packages/torch/nn/functional.py:3103: UserWarning: The default behavior for interpolate/upsample with float scale_factor changed in 1.6.0 to align with other frameworks/libraries, and now uses scale_factor directly, instead of relying on the computed output size. If you wish to restore the old behavior, please set recompute_scale_factor=True. See the documentation of nn.Upsample for details.
# ...

# %%
learn = cnn_learner(data_cleaned, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.601243</td>
#       <td>0.884074</td>
#       <td>0.340102</td>
#       <td>04:43</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.282668</td>
#       <td>0.782817</td>
#       <td>0.243655</td>
#       <td>04:43</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.060984</td>
#       <td>0.793018</td>
#       <td>0.274112</td>
#       <td>04:42</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.903072</td>
#       <td>0.963597</td>
#       <td>0.319797</td>
#       <td>04:42</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.801007</td>
#       <td>0.779392</td>
#       <td>0.263959</td>
#       <td>04:42</td>
#     </tr>
#     <tr>
#       <td>5</td>
# ...

# %%
learn.save('stage-3')

# %%
learn.unfreeze()

# %%
learn.lr_find()

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(2, max_lr=slice(3e-5,3e-4))

# %%
learn.save('stage-4')

# %%
learn.load('stage-4')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %%
learn.export()

# %% [markdown]
# #Streamlit

# %%
from pyngrok import ngrok
# !pgrep streamlit
ngrok.kill()
from pyngrok import ngrok
import streamlit as st

# %%
# URL input
# %%writefile dermatitis.py
#Importing Libraries
import PIL
import os
import csv
import urllib

import streamlit as st # Web application
from PIL import Image # Image processing
import requests # image URL requesting
from io import BytesIO # Image conversion

import numpy as np # linear algebra
import pandas as pd # data processing

from fastai.vision import *
from fastai.imports import *

#Setting up Variables
classes = ['eczema','measles','melanoma']


#Create a title and a sub-title
st.title("Dermatitis Detection")
st.write("Detect if someone has either eczema, measles, or melanoma by using Machine Learning with Python - By Varun Chandrashekhar")

#Open and Display an Image
st1_image = PIL.Image.open('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/doctor.PNG')
st.image(st1_image, caption = 'Confusion Matrix (Showing Accuracy of Machine Learning Model)', use_column_width=False)

# store the user input into a variable
URL_input = st.text_input('Enter Image URL to Classify... ', 'https://www.thehealthy.com/wp-content/uploads/2018/06/dry-skin-760x506.jpg')
#Set a subheader and display the users input
st.subheader('User Input: ')
st.write(URL_input)

#Writing URL into csv file
file = open('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/User Input/URL','w')
file.write(URL_input)
file.close()

#Downloading Image from link
with st.spinner('Dowloading Image...'):
  download_images('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/User Input/URL', '/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/User Input')

#Open and Display an Users Input Image
with st.spinner('Displaying Image...'):
  st_user_image = PIL.Image.open('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/User Input/00000000.jpg')
  st.image(st_user_image, caption = 'Your Image')

#Setting Up The Text for Classification
with st.spinner('Processing Image.....'):
   path = Path('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/data/dermatitis')
   data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
           ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)
   with st.spinner('Exporting Model.....'):
    learn = cnn_learner(data, models.resnet34, metrics=error_rate)
    learn.load('stage-4')
    learn.export()
    defaults.device = torch.device('cpu')
    learn = load_learner(path)
    with st.spinner('Classifying.....'):
      user_input_img = open_image('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/User Input/00000000.jpg')
      pred_class,pred_idx,outputs = learn.predict(user_input_img)
      st.write("Predicted Class : ")
      st.write(pred_class)
      st.write(pred_idx)
      st.write(outputs)

# %%
#Alternative Code for image upload
# %%writefile dermatitis.py
#Importing Libraries
import PIL
import os
import cv2
import urllib

import streamlit as st # Web application
from PIL import Image, ImageOps # Image processing
import requests # image URL requesting
from io import BytesIO # Image conversion

import numpy as np # linear algebra
import pandas as pd # data processing

from fastai.vision import *
from fastai.imports import *

#Setting up Variables
classes = ['eczema','measles','melanoma']

#Create a title and a sub-title
st.title("Dermatitis Detection")
st.write("Detect if someone has either eczema, measles, or melanoma by using Machine Learning with Python - By Varun Chandrashekhar")

#Open and Display an Image
st1_image = PIL.Image.open('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/Dermatitis Detection.png')
st.image(st1_image, caption =False)

# Uploading Image File
#Set warnings to False
st.set_option('deprecation.showfileUploaderEncoding',False)

#User Input
st.subheader("User Input:")
#Uploading image file
file = st.file_uploader("Please upload image of skin", type=["jpg","png"], use_column_width=True)

if file is None:
  st.text ("Please upload an image file")
else:
  image_input = PIL.Image.open(file)
  #download_images(file, '/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/User Input')
  st.image(image_input, use_column_width=True)
  #Save Image
  image_input.save('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/User Input/00000000.jpg', 'JPEG')#open_image('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/User Input/00000000.jpg', 'JPG')
  #Setting Up The Text for Classification
  with st.spinner('Processing Image.....'):
    path = Path('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/data/dermatitis')
    data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
            ds_tfms=get_transforms(), size=224, num_workers=4).normalize(imagenet_stats)
    with st.spinner('Exporting Model.....'):
      learn = cnn_learner(data, models.resnet34, metrics=error_rate)
      learn.load('stage-4')
      learn.export()
      defaults.device = torch.device('cpu')
      learn = load_learner(path)
      with st.spinner('Classifying.....'):
        user_input_img = open_image('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/User Input/00000000.jpg')
        pred_class,pred_idx,outputs = learn.predict(user_input_img)
        st.subheader("Predicted Class : ")
        st.success(str(pred_class))
        accuracy = outputs[pred_idx]
        accuracy = str(accuracy)
        accuracy = accuracy[7:-1]
        st.subheader("Accuracy: ")
        st.success(accuracy)
  
  
  #Set a subheader
  st.subheader('Confusion Matrix: ')
  # Show  the data as a image
  st2_image = PIL.Image.open('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/Confusion_Matrix.PNG')
  st.image(st2_image, caption = 'Confusion Matrix (Showing Accuracy of Machine Learning Model)', use_column_width=False)

  #Set a subheader
  st.subheader('Data Matrix: ')
  # Show  the data as a image
  st3_image = PIL.Image.open('/content/gdrive/My Drive/Machine Learning Web Application/Dermatitis Doctor/Data_1.PNG')
  st.image(st3_image, caption = 'Confusion Matrix (Showing Data that was used)', use_column_width=False)

# %%
# !nohup streamlit run dermatitis.py &

# %%
# !streamlit run dermatitis.py &>/dev/null&
# Setup a tunnel to the streamlit port 8501
public_url = ngrok.connect(port='8501')
public_url

# %%
from google.colab import drive
drive.mount('/content/drive')
